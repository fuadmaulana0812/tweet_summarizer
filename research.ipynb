# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5

# %%
import pandas as pd

# %%
df = pd.read_excel('Twitter Accounts_DeSci AI Agent_210325.xlsx', skiprows=2)

# Filter rows where "Twitter Account" starts with "https"
df_filtered = df[df["Twitter Account"].astype(str).str.startswith("https")]

# Extract username from the "Twitter Account" URL
df_filtered["Username"] = df_filtered["Twitter Account"].str.extract(r"https://x\.com/([^/]+)")

# Convert the usernames to a list
user_list = df_filtered["Username"].tolist()
# Out:
# C:\Users\fuadm\AppData\Local\Temp\ipykernel_11308\958860548.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered["Username"] = df_filtered["Twitter Account"].str.extract(r"https://x\.com/([^/]+)")

# %%
df = pd.read_excel('Twitter Accounts_DeSci AI Agent_210325.xlsx', skiprows=2)
df
# Out:
#     Unnamed: 0  Unnamed: 1  No.                Twitter Account  \
# 0          NaN         NaN    1         https://x.com/vita_dao
# 1          NaN         NaN    2   https://x.com/pumpdotscience
# 2          NaN         NaN    3      https://x.com/Big_Pharmai
# 3          NaN         NaN    4      https://x.com/ResearchHub
# 4          NaN         NaN    5          https://x.com/cryodao
# 5          NaN         NaN    6      https://x.com/bioprotocol
# 6          NaN         NaN    7          https://x.com/psy_dao
# 7          NaN         NaN    8       https://x.com/valley_dao
# 8          NaN         NaN    9  https://x.com/endrarediseases
# 9          NaN         NaN   10         https://x.com/daohydra
# 10         NaN         NaN   11     https://x.com/Cerebrum_DAO
# 11         NaN         NaN   12    https://x.com/longcovidlabs
# 12         NaN         NaN   13       https://x.com/yesnoerror
# 13         NaN         NaN   14         https://x.com/HairDAO_
# 14         NaN         NaN   15    https://x.com/QuantumBioDAO
# 15         NaN         NaN   16       https://x.com/DeSciWorld
# 16         NaN         NaN   17         https://x.com/arxiv_sh
# 17         NaN         NaN   18         https://x.com/neirylab
# 18         NaN         NaN   19         https://x.com/crisprAI
# 19         NaN         NaN   20     https://x.com/Nuclease_DAO
# 20         NaN         NaN   21      https://x.com/athena_DAO_
# 21         NaN         NaN   22       https://x.com/TrackedBio
# 22         NaN         NaN   23    https://x.com/Artemisinin69
# 23         NaN         NaN   24          https://x.com/betaNMN
# 24         NaN         NaN   25        https://x.com/BerbeQuer
# 25         NaN         NaN   26           https://x.com/HESDHM
# 26         NaN         NaN   27    https://x.com/EGCGonpumpsci
# 27         NaN         NaN   28  https://x.com/trolpumpscience
# 28         NaN         NaN   29  https://x.com/ginsenoside_rh2
# 29         NaN         NaN   30     https://x.com/caffeinepump
# 30         NaN         NaN   31       https://x.com/GosCateXyz
# 31         NaN         NaN   32         https://x.com/EGCGxSFN
# 32         NaN         NaN   33     https://x.com/BBiotin35738
# 33         NaN         NaN   34       https://x.com/RealPomTea
# 34         NaN         NaN   35    https://x.com/BerberinePuni
# 35         NaN         NaN   36       https://x.com/DesciForge
# 36         NaN         NaN   37          https://x.com/MycoDAO
# 37         NaN         NaN   38         https://x.com/BeeARDai
# 38         NaN         NaN   39                            NaN
# 39         NaN         NaN   40                            NaN
#
#                  Account Name     Ticker         X account Added Date
# 0                     VitaDAO      $vita         @vita_dao        NaT
# 1                pump.science  $rif $uro   @pumpdotscience        NaT
# 2                 big pharmai     $drugs      @Big_Pharmai        NaT
# 3                Research Hub       $rsc      @ResearchHub        NaT
# 4                     CryoDAO       $rsc          @cryodao        NaT
# 5                BIO Protocol       $bio      @bioprotocol        NaT
# 6                      PsyDAO       $psy          @psy_dao        NaT
# 7                   ValleyDAO      $grow       @valley_dao        NaT
# 8                   Curetopia     $cures  @endrarediseases        NaT
# 9                    HydraDAO     $hydra         @daohydra        NaT
# 10                CerebrumDAO    $neuron     @Cerebrum_DAO        NaT
# 11            Long COVID Labs        NaN    @longcovidlabs        NaT
# 12                 YesNoError       $yne       @yesnoerror        NaT
# 13                    HairDAO        NaN         @HairDAO_        NaT
# 14        Quantum Biology DAO        NaN    @QuantumBioDAO        NaT
# 15                DeSci World        NaN       @DeSciWorld        NaT
# 16                   arXiv.sh     $arxiv         @arxiv_sh        NaT
# 17  Neiry (Creator of Pythia)    $pythia         @neirylab        NaT
# 18                  CRISPR AI    $crispr         @crisprAI        NaT
# 19                NucleaseDAO        NaN     @Nuclease_DAO        NaT
# 20                  AthenaDAO    $Athena      @athena_DAO_        NaT
# 21                 Trackedbio        NaN       @TrackedBio        NaT
# 22                Artemisinin       $Art    @Artemisinin69        NaT
# 23                        NaN        NaN               NaN 2025-02-08
# 24                        NaN        NaN               NaN 2025-02-08
# 25                        NaN        NaN               NaN 2025-02-08
# 26                        NaN        NaN               NaN 2025-02-08
# 27                        NaN        NaN               NaN 2025-02-08
# 28                        NaN        NaN               NaN 2025-02-08
# 29                        NaN        NaN               NaN 2025-02-08
# 30                        NaN        NaN               NaN 2025-02-08
# 31                        NaN        NaN               NaN 2025-02-08
# 32                        NaN        NaN               NaN 2025-02-08
# 33                        NaN        NaN               NaN 2025-02-08
# 34                        NaN        NaN               NaN 2025-02-08
# 35                        NaN        NaN               NaN 2025-02-08
# 36                        NaN        NaN               NaN        NaT
# 37                        NaN        NaN               NaN        NaT
# 38                        NaN        NaN               NaN        NaT
# 39                        NaN        NaN               NaN        NaT

# %%
len(user_list)
# Out:
# 38

# %%
user_list
# Out:
# ['vita_dao',
#  'pumpdotscience',
#  'Big_Pharmai',
#  'ResearchHub',
#  'cryodao',
#  'bioprotocol',
#  'psy_dao',
#  'valley_dao',
#  'endrarediseases',
#  'daohydra',
#  'Cerebrum_DAO',
#  'longcovidlabs',
#  'yesnoerror',
#  'HairDAO_',
#  'QuantumBioDAO',
#  'DeSciWorld',
#  'arxiv_sh',
#  'neirylab',
#  'crisprAI',
#  'Nuclease_DAO',
#  'athena_DAO_',
#  'TrackedBio',
#  'Artemisinin69',
#  'betaNMN',
#  'BerbeQuer',
#  'HESDHM',
#  'EGCGonpumpsci',
#  'trolpumpscience',
#  'ginsenoside_rh2',
#  'caffeinepump',
#  'GosCateXyz',
#  'EGCGxSFN',
#  'BBiotin35738',
#  'RealPomTea',
#  'BerberinePuni',
#  'DesciForge',
#  'MycoDAO',
#  'BeeARDai']

# %%
from datetime import datetime, timedelta, timezone

now = datetime.now(tz=timezone(timedelta(hours=-5)))
end = now - timedelta(hours=3)
now, end
# Out:
# (datetime.datetime(2025, 3, 23, 22, 34, 22, 344013, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))),
#  datetime.datetime(2025, 3, 23, 19, 34, 22, 344013, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))))
